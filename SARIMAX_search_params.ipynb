# %%
# -*- coding: utf-8 -*-
from pandas import read_csv, DataFrame
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from itertools import product
import warnings
from sklearn.metrics import r2_score

import pandas as pd
import numpy as np
from scipy import stats

import statsmodels.api as sm

#Поиск лучших параметров по критерию Акаике

# %%
dataset = read_csv('training.csv',
                     ',',
                     index_col=['Date'],
                     parse_dates=['Date'],
                     dayfirst=True)

# %%
dataset['Value_box'], lmbda = stats.boxcox(dataset.Value)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

Qs = range(0, 3)
qs = range(0, 11)
Ps = range(0, 1)
ps = range(0, 2)
d = 1
D = 0
S = range(12,13 )

parameters = product(ps, qs, Ps, Qs, S)
parameters_list = list(parameters)

results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')

for param in parameters_list:
    try:
        model = sm.tsa.statespace.SARIMAX(dataset.Value, order=(param[0], d, param[1]), seasonal_order = (param[2], D, param[3], param[4])).fit(disp = -1)
    except:
        print ('waring parametrs:', param)
        continue
    print ('Computing...')
    if model.aic < best_aic:
        best_model = model
        best_aic = model.aic
        best_param = param
        print (param, model.aic)
    results.append([param, model.aic])
    

warnings.filterwarnings('default')

result_table = DataFrame(results)
result_table.columns = ['parameters', 'aic']
print (result_table.sort_values(by = 'aic', ascending = [True]).head())
# Out:
# waring parametrs: (0, 0, 0, 0, 12)
# Computing...
# (0, 0, 0, 1, 12) 348.780303091
# Computing...
# (0, 0, 0, 2, 12) 344.713936014
# Computing...
# (0, 1, 0, 0, 12) 287.000222675
# Computing...
# Computing...
# (0, 1, 0, 2, 12) 284.337156431
# Computing...
# (0, 2, 0, 0, 12) 274.353802556
# Computing...
# Computing...
# (0, 2, 0, 2, 12) 268.838909268
# Computing...
# (0, 3, 0, 0, 12) 266.970397629
# Computing...
# Computing...
# (0, 3, 0, 2, 12) 262.509461691
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# (1, 0, 0, 2, 12) 257.245156966
# Computing...
# (1, 1, 0, 0, 12) 255.641354586
# Computing...
# (1, 1, 0, 1, 12) 255.507342056
# Computing...
# (1, 1, 0, 2, 12) 247.151493249
# Computing...
# Computing...
# Computing...
# (1, 2, 0, 2, 12) 245.989110227
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# (1, 5, 0, 2, 12) 239.945856753
# Computing...
# Computing...
# Computing...
# (1, 6, 0, 2, 12) 239.422835886
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
# Computing...
#           parameters         aic
# 52  (1, 6, 0, 2, 12)  239.422836
# 49  (1, 5, 0, 2, 12)  239.945857
# 55  (1, 7, 0, 2, 12)  241.333725
# 58  (1, 8, 0, 2, 12)  244.156899
# 40  (1, 2, 0, 2, 12)  245.989110

# %%
#Лучшие по критерию Акаике
# p = 1
# q = 6
# P = 0
# Q = 2
# S = 12
